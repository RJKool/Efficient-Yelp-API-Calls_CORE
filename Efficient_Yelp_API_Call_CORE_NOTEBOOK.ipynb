# %%
# Standard Imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Additional Imports
# os - for saving and loading files
# json - to work with json files
# math - to round up results
# time - to add a short pause to not overwhelm the server
import os, json, math, time
from yelpapi import YelpAPI   # to make yelp api calls
from tqdm.notebook import tqdm_notebook   # to make a progress bar from tqdm_notebook

# %%
# CREDENTIALS AND ACCESSING THE API
with open('/Users/Rashad/.secret/yelp_api_rashadc.json') as rc:
    login = json.load(rc)

# %%
#quick display of the variable 'login' dictionary keys
login.keys()
# Out:
# dict_keys(['client-id', 'api-key'])

# %%
# Instantiate YelpAPI Variable
yelp_api = YelpAPI(login['api-key'], timeout_s=5.0)

# %%
### DEFINE SEARCH ###
# set your API call parameters 
LOCATION = 'Chicago'
TERM = 'deer'

# %%
# Specifying JSON_FILE filename (can include a folder)
# include the search terms in the filename
JSON_FILE = "Data/results_in_progress_Chicago_pizza.json"

# %%
#Function to create .json file and check it one already exists.

def create_json_file(JSON_FILE,  delete_if_exists=False):
        
    ## Check if JSON_FILE exists
    file_exists = os.path.isfile(JSON_FILE)
    
    ## If it DOES exist:
    if file_exists == True:
        
        ## Check if user wants to delete if exists
        if delete_if_exists==True:
            
            print(f"[!] {JSON_FILE} already exists. Deleting previous file...")
            ## delete file and confirm it no longer exits.
            os.remove(JSON_FILE)
            ## Recursive call to function after old file deleted
            create_json_file(JSON_FILE,delete_if_exists=False)
        else:
            print(f"[i] {JSON_FILE} already exists.")            
            
            
    ## If it does NOT exist:
    else:
        
        ## INFORM USER AND SAVE EMPTY LIST
        print(f"[i] {JSON_FILE} not found. Saving empty list to new file.")
        
        ## CREATE ANY NEEDED FOLDERS
        # Get the Folder Name only
        folder = os.path.dirname(JSON_FILE)
        
        ## If JSON_FILE included a folder:
        if len(folder)>0:
            # create the folder
            os.makedirs(folder,exist_ok=True)
        ## Save empty list to start the json file
        with open(JSON_FILE,'w') as f:
            json.dump([],f)

# %% [markdown]
# # Creating JSON file and process search pages needed.

# %%
## Create a new empty json file (exist the previous if it exists)
create_json_file(JSON_FILE, delete_if_exists=True)
# Out:
# [!] Data/results_in_progress_Chicago_pizza.json already exists. Deleting previous file...
# [i] Data/results_in_progress_Chicago_pizza.json not found. Saving empty list to new file.

# %%
## Load previous results and use len of results for offset
with open(JSON_FILE,'r') as f:
    previous_results = json.load(f)
    
## set offset based on previous results
n_results = len(previous_results)

# %%
#confirming empty json file was created.
print(f'- {n_results} previous results found.')
# Out:
# - 0 previous results found.

# %% [markdown]
# # API call to retrieve data.

# %%
# yelp_api variable's search_query method to perform our API call
results = yelp_api.search_query(location=LOCATION,
                                term=TERM,
                                offset=n_results)

# %%
#quick view of data type
type(results)
# Out:
# dict

# %%
#quick view of dictionary keys
results.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
## How many did we get the details for?  This is the pagination size.
results_per_page = len(results['businesses'])

# Use math.ceil to round up for the total number of pages of results.
n_pages = math.ceil((results['total']-n_results) / results_per_page)

print(f'Total number of pages is {n_pages}')
# Out:
# Total number of pages is 41

# %%
print(f'n_results: {len(previous_results)} pluS {results_per_page} = {(len(previous_results) + results_per_page)}')
# Out:
# n_results: 0 pluS 20 = 20

# %% [markdown]
# # Exploring variable dictionary `results` to find target data.

# %%
results['businesses']
# Out:
# [{'id': 'PZe0q_153VHUnaR-8dOTJg',
#   'alias': 'the-dearborn-chicago-2',
#   'name': 'The Dearborn',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eSXeGiq2bRUjy7KOER4jeg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-dearborn-chicago-2?adjust_creative=Rb-Ho11X0wH2IQkZpl-sCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Rb-Ho11X0wH2IQkZpl-sCA',
#   'review_count': 2074,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'beer_and_wine', 'title': 'Beer, Wine & Spirits'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.8842528, 'longitude': -87.6293151},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '145 N Dearborn St',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60602',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['145 N Dearborn St', 'Chicago, IL 60602']},
#   'phone': '+13123841242',
#   'display_phone': '(312) 384-1242',
#   'distance': 4633.348426554309},
#  {'id': 'VFv_EfqRQN2RTh9Nmj3tNA',
#   'alias': 'arctic-circle-taxidermy-chicago',
#   'name': 'Arctic Circle Taxidermy',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/EE06-p9pAI_QOH7Pzdb_Zg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/arctic-circle-taxidermy-chicago?adjust_creative=Rb-Ho11X0wH2IQkZpl-sCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Rb-Ho11X0wH2IQkZpl-sCA',
#   'review_count': 6,
#   'categories': [{'alias': 'taxidermy', 'title': 'Taxidermy'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 41.9528579711914,
#    'longitude': -87.7685394287109},
#   'transactions': [],
#   'location': {'address1': '5637 W Irving Park Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60634',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['5637 W Irving Park Rd', 'Chicago, IL 60634']},
#   'phone': '+17732868000',
#   'display_phone': '(773) 286-8000',
#   'distance': 9201.472587826273},
#  {'id': 'WqKKvM3sUszaIqneaa8EKA',
#   'alias': 'waterfall-glen-forest-preserve-darien-2',
#   'name': 'Waterfall Glen Forest Preserve',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/HmSfAdQW2hpu6ouZESa7Wg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/waterfall-glen-forest-preserve-darien-2?adjust_creative=Rb-Ho11X0wH2IQkZpl-sCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Rb-Ho11X0wH2IQkZpl-sCA',
#   'review_count': 141,
#   'categories': [{'alias': 'parks', 'title': 'Parks'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.723035754423414,
#    'longitude': -87.97261748395891},
#   'transactions': [],
#   'location': {'address1': 'Intersection Of Cass And Northgate Rd',
#    'address2': None,
#    'address3': '',
#    'city': 'Darien',
#    'zip_code': '60561',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['Intersection Of Cass And Northgate Rd',
#     'Darien, IL 60561']},
#   'phone': '+16309337200',
#   'display_phone': '(630) 933-7200',
#   'distance': 31736.718352702494},
#  {'id': 'Sb7Jk4c4jv7HLblNGRxqKQ',
#   'alias': 'sideshow-gallery-chicago',
#   'name': 'Sideshow Gallery',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/PBLs0Jwo1Y7MQHIXJLx7mQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sideshow-gallery-chicago?adjust_creative=Rb-Ho11X0wH2IQkZpl-sCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Rb-Ho11X0wH2IQkZpl-sCA',
#   'review_count': 24,
#   'categories': [{'alias': 'galleries', 'title': 'Art Galleries'},
#    {'alias': 'antiques', 'title': 'Antiques'},
#    {'alias': 'spiritual_shop', 'title': 'Spiritual Shop'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 41.922305053523,
#    'longitude': -87.68729102566006},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2219 N Western Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60647',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['2219 N Western Ave', 'Chicago, IL 60647']},
#   'phone': '+17732761300',
#   'display_phone': '(773) 276-1300',
#   'distance': 2063.0477068771074},
#  {'id': 'fLwNhXatcSoQEI8XeFbrtg',
#   'alias': 'bangers-and-lace-wicker-park-chicago-2',
#   'name': 'Bangers & Lace Wicker Park',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fHPirOU17bRmeBTKg5rPoA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bangers-and-lace-wicker-park-chicago-2?adjust_creative=Rb-Ho11X0wH2IQkZpl-sCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Rb-Ho11X0wH2IQkZpl-sCA',
#   'review_count': 609,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.90357, 'longitude': -87.67023},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$',
#   'location': {'address1': '1670 W Division St',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60622',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1670 W Division St', 'Chicago, IL 60622']},
#   'phone': '+17732526499',
#   'display_phone': '(773) 252-6499',
#   'distance': 645.4781323111192},
#  {'id': 'L9Ick2vNCi0zh6_m0tEvEg',
#   'alias': 'st-paul-woods-morton-grove-2',
#   'name': 'St. Paul Woods',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/qis59xJeW3BVXJGJyCQxUw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/st-paul-woods-morton-grove-2?adjust_creative=Rb-Ho11X0wH2IQkZpl-sCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Rb-Ho11X0wH2IQkZpl-sCA',
#   'review_count': 2,
#   'categories': [{'alias': 'parks', 'title': 'Parks'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 42.0308871065171,
#    'longitude': -87.7910324909724},
#   'transactions': [],
#   'location': {'address1': '6594 Oakton St',
#    'address2': '',
#    'address3': '',
#    'city': 'Morton Grove',
#    'zip_code': '60053',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['6594 Oakton St', 'Morton Grove, IL 60053']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 16826.79147240434},
#  {'id': 'Hf2AdiXnlDxV0ZIBczClBQ',
#   'alias': 'north-branch-trail-chicago',
#   'name': 'North Branch Trail',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/SPZiPAF_6vMeWP2Kh_9P0Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/north-branch-trail-chicago?adjust_creative=Rb-Ho11X0wH2IQkZpl-sCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Rb-Ho11X0wH2IQkZpl-sCA',
#   'review_count': 50,
#   'categories': [{'alias': 'parks', 'title': 'Parks'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.9974031299353,
#    'longitude': -87.7854656428099},
#   'transactions': [],
#   'location': {'address1': '6300 W Devon Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60645',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['6300 W Devon Ave', 'Chicago, IL 60645']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 13572.864453214663},
#  {'id': 'Rxr-cdO6QHRCXKKyfm8bvA',
#   'alias': 'quality-time-chicago',
#   'name': 'Quality Time',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/2ieBkNEKgJJn_6JgUG03Iw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/quality-time-chicago?adjust_creative=Rb-Ho11X0wH2IQkZpl-sCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Rb-Ho11X0wH2IQkZpl-sCA',
#   'review_count': 23,
#   'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.93226, 'longitude': -87.70148},
#   'transactions': [],
#   'location': {'address1': '2934 W Diversey Ave',
#    'address2': '',
#    'address3': None,
#    'city': 'Chicago',
#    'zip_code': '60647',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['2934 W Diversey Ave', 'Chicago, IL 60647']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 3596.1793576934965},
#  {'id': 'XsGNjQODQGHMUPKrS_xEnA',
#   'alias': 'the-capital-grille-chicago-4',
#   'name': 'The Capital Grille',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/rF_FKwmnRhbprocTpVrQ5Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-capital-grille-chicago-4?adjust_creative=Rb-Ho11X0wH2IQkZpl-sCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Rb-Ho11X0wH2IQkZpl-sCA',
#   'review_count': 939,
#   'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.893506, 'longitude': -87.622498},
#   'transactions': ['delivery', 'pickup'],
#   'price': '$$$',
#   'location': {'address1': '633 N Saint Clair St',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60611',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['633 N Saint Clair St', 'Chicago, IL 60611']},
#   'phone': '+13123379400',
#   'display_phone': '(312) 337-9400',
#   'distance': 4754.129339543692},
#  {'id': 'rYc8maCCT-zleaQdEBKweA',
#   'alias': 'gaslight-coffee-roasters-chicago',
#   'name': 'Gaslight Coffee Roasters',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m_vGjNmK5Ukdei3--ViRJQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gaslight-coffee-roasters-chicago?adjust_creative=Rb-Ho11X0wH2IQkZpl-sCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Rb-Ho11X0wH2IQkZpl-sCA',
#   'review_count': 296,
#   'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.92458, 'longitude': -87.69972},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '2385 N Milwaukee Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60647',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['2385 N Milwaukee Ave', 'Chicago, IL 60647']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 2826.78654437995},
#  {'id': 'DR-438nexZbyr4HrmdjPcg',
#   'alias': 'ryerson-woods-forest-preserve-riverwoods',
#   'name': 'Ryerson Woods Forest Preserve',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7GzGwicuPD-PNzcKuAE1zw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ryerson-woods-forest-preserve-riverwoods?adjust_creative=Rb-Ho11X0wH2IQkZpl-sCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Rb-Ho11X0wH2IQkZpl-sCA',
#   'review_count': 20,
#   'categories': [{'alias': 'hiking', 'title': 'Hiking'},
#    {'alias': 'landmarks', 'title': 'Landmarks & Historical Buildings'},
#    {'alias': 'parks', 'title': 'Parks'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 42.18172, 'longitude': -87.914956},
#   'transactions': [],
#   'location': {'address1': '21950 N Riverwoods Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Riverwoods',
#    'zip_code': '60015',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['21950 N Riverwoods Rd', 'Riverwoods, IL 60015']},
#   'phone': '+18479683321',
#   'display_phone': '(847) 968-3321',
#   'distance': 36459.92157012273},
#  {'id': 'll2dtwffNINOpPAZt5gDhg',
#   'alias': 'deer-grove-forest-preserve-palatine',
#   'name': 'Deer Grove Forest Preserve',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IzEuSm72bb0Y63D1Pxys7A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/deer-grove-forest-preserve-palatine?adjust_creative=Rb-Ho11X0wH2IQkZpl-sCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Rb-Ho11X0wH2IQkZpl-sCA',
#   'review_count': 27,
#   'categories': [{'alias': 'parks', 'title': 'Parks'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 42.1526799, 'longitude': -88.04273},
#   'transactions': [],
#   'location': {'address1': 'Deer Grove Forest Preserve',
#    'address2': '',
#    'address3': '',
#    'city': 'Palatine',
#    'zip_code': '60074',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['Deer Grove Forest Preserve', 'Palatine, IL 60074']},
#   'phone': '+17083669420',
#   'display_phone': '(708) 366-9420',
#   'distance': 42376.21327307872},
#  {'id': 'HkjLE16WEPkF57sfp65rpA',
#   'alias': 'sportsmans-club-chicago',
#   'name': "Sportsman's Club",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/dOf1NT5Wsyb5D1wPcT0g1Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sportsmans-club-chicago?adjust_creative=Rb-Ho11X0wH2IQkZpl-sCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Rb-Ho11X0wH2IQkZpl-sCA',
#   'review_count': 128,
#   'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.8989868164062,
#    'longitude': -87.6873092651367},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '948 N Western Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60622',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['948 N Western Ave', 'Chicago, IL 60622']},
#   'phone': '+18722068054',
#   'display_phone': '(872) 206-8054',
#   'distance': 1045.5082250847506},
#  {'id': 'kSDupSRuYSQKCQ4f0TABWw',
#   'alias': 'chicago-riverwalk-chicago-3',
#   'name': 'Chicago Riverwalk',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/SNZq7euC8q9C0jh0tq7A_w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/chicago-riverwalk-chicago-3?adjust_creative=Rb-Ho11X0wH2IQkZpl-sCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Rb-Ho11X0wH2IQkZpl-sCA',
#   'review_count': 218,
#   'categories': [{'alias': 'landmarks',
#     'title': 'Landmarks & Historical Buildings'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.8875448, 'longitude': -87.6174791},
#   'transactions': [],
#   'location': {'address1': '400 E Lower Wacker Dr',
#    'address2': '',
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60601',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['400 E Lower Wacker Dr', 'Chicago, IL 60601']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 5360.399821065001},
#  {'id': 'VL5XjVU2PPrIZsh4l4aG6g',
#   'alias': 'forest-preserve-district-of-cook-county-illinois-river-forest',
#   'name': 'Forest Preserve District of Cook County, Illinois',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tyBJHrbBiXNlTDxTBR3FcQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/forest-preserve-district-of-cook-county-illinois-river-forest?adjust_creative=Rb-Ho11X0wH2IQkZpl-sCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Rb-Ho11X0wH2IQkZpl-sCA',
#   'review_count': 12,
#   'categories': [{'alias': 'active', 'title': 'Active Life'},
#    {'alias': 'publicservicesgovt', 'title': 'Public Services & Government'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.88978483984597,
#    'longitude': -87.8059156334449},
#   'transactions': [],
#   'location': {'address1': '536 North Harlem Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'River Forest',
#    'zip_code': '60305',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['536 North Harlem Ave', 'River Forest, IL 60305']},
#   'phone': '+18008703666',
#   'display_phone': '(800) 870-3666',
#   'distance': 10743.520316011714},
#  {'id': 'lobzkyvKpXDMCrfd3mkasg',
#   'alias': 'prairie-wolf-deerfield',
#   'name': 'Prairie Wolf',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/V4l5ZxeHzZASrcHFUr2Ntw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/prairie-wolf-deerfield?adjust_creative=Rb-Ho11X0wH2IQkZpl-sCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Rb-Ho11X0wH2IQkZpl-sCA',
#   'review_count': 3,
#   'categories': [{'alias': 'parks', 'title': 'Parks'},
#    {'alias': 'hiking', 'title': 'Hiking'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 42.199791753196735,
#    'longitude': -87.85467263765304},
#   'transactions': [],
#   'location': {'address1': '11403 W Hwy 22',
#    'address2': '',
#    'address3': None,
#    'city': 'Deerfield',
#    'zip_code': '60015',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['11403 W Hwy 22', 'Deerfield, IL 60015']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 35870.19526312168},
#  {'id': 'QEArQCNQdBsrmOEszghrHQ',
#   'alias': 'labagh-woods-river-forest',
#   'name': 'LaBagh Woods',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/8BbYd8FoE2paXN48DvbT9A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/labagh-woods-river-forest?adjust_creative=Rb-Ho11X0wH2IQkZpl-sCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Rb-Ho11X0wH2IQkZpl-sCA',
#   'review_count': 21,
#   'categories': [{'alias': 'parks', 'title': 'Parks'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 41.975732, 'longitude': -87.748021},
#   'transactions': [],
#   'location': {'address1': '536 North Harlem Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'River Forest',
#    'zip_code': '60305',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['536 North Harlem Ave', 'River Forest, IL 60305']},
#   'phone': '+18008703666',
#   'display_phone': '(800) 870-3666',
#   'distance': 9764.616511148522},
#  {'id': 'bNXpwTSavHBV9zBk2lUlGA',
#   'alias': 'schwa-chicago',
#   'name': 'Schwa',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WoQ_WcnPMk5GxoCQmaezpw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/schwa-chicago?adjust_creative=Rb-Ho11X0wH2IQkZpl-sCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Rb-Ho11X0wH2IQkZpl-sCA',
#   'review_count': 577,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 41.90892, 'longitude': -87.66793},
#   'transactions': [],
#   'price': '$$$$',
#   'location': {'address1': '1466 N Ashland Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Chicago',
#    'zip_code': '60622',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['1466 N Ashland Ave', 'Chicago, IL 60622']},
#   'phone': '+17732521466',
#   'display_phone': '(773) 252-1466',
#   'distance': 913.6804095380663},
#  {'id': 'dJjhhMSPiiAg9PO_CcmkqQ',
#   'alias': 'skokie-northshore-sculpture-park-skokie',
#   'name': 'Skokie Northshore Sculpture Park',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/iCWn_TGbP0xOLB3fkz--8w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/skokie-northshore-sculpture-park-skokie?adjust_creative=Rb-Ho11X0wH2IQkZpl-sCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Rb-Ho11X0wH2IQkZpl-sCA',
#   'review_count': 36,
#   'categories': [{'alias': 'parks', 'title': 'Parks'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 42.0116529461899,
#    'longitude': -87.7110190459106},
#   'transactions': [],
#   'location': {'address1': '',
#    'address2': '',
#    'address3': '',
#    'city': 'Skokie',
#    'zip_code': '60076',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['Skokie, IL 60076']},
#   'phone': '+18476794265',
#   'display_phone': '(847) 679-4265',
#   'distance': 12156.60746638371},
#  {'id': 'TCTgr-KpKHut3JPoJTTTFg',
#   'alias': 'buffalo-creek-forest-preserve-long-grove',
#   'name': 'Buffalo Creek Forest Preserve',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yK62fkQ1ZbatsC5Gus0_mA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/buffalo-creek-forest-preserve-long-grove?adjust_creative=Rb-Ho11X0wH2IQkZpl-sCA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Rb-Ho11X0wH2IQkZpl-sCA',
#   'review_count': 17,
#   'categories': [{'alias': 'parks', 'title': 'Parks'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 42.159912697537024,
#    'longitude': -88.00671066347655},
#   'transactions': [],
#   'location': {'address1': '18163 W Checker Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Long Grove',
#    'zip_code': '60047',
#    'country': 'US',
#    'state': 'IL',
#    'display_address': ['18163 W Checker Rd', 'Long Grove, IL 60047']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 39249.6738874328}]

# %% [markdown]
# # Loop with TQDM progress bar to load remaining pages into JSON file.

# %%
for i in tqdm_notebook( range(1,n_pages+1)):
    
    ## Read in results in progress file and check the length
    with open(JSON_FILE, 'r') as f:
        previous_results = json.load(f)
    ## save number of results for to use as offset
    n_results = len(previous_results)
    
    if (n_results + results_per_page) > 1000:
        print('Exceeded 500 api calls. Stopping loop.')
        break
    
    ## use n_results as the OFFSET 
    results = yelp_api.search_query(location=LOCATION,
                                    term=TERM, 
                                    offset=n_results)
    
    ## append new results and save to file
    previous_results.extend(results['businesses'])
    
    # display(previous_results)
    with open(JSON_FILE,'w') as f:
        json.dump(previous_results,f)
    
    time.sleep(2.2)
# Out:
#   0%|          | 0/41 [00:00<?, ?it/s]

# %%
#Convert final JSON file to dataframe.
df = pd.read_json(JSON_FILE)
df.head()
# Out:
#                        id                                    alias  \
# 0  PZe0q_153VHUnaR-8dOTJg                   the-dearborn-chicago-2
# 1  VFv_EfqRQN2RTh9Nmj3tNA          arctic-circle-taxidermy-chicago
# 2  WqKKvM3sUszaIqneaa8EKA  waterfall-glen-forest-preserve-darien-2
# 3  Sb7Jk4c4jv7HLblNGRxqKQ                 sideshow-gallery-chicago
# 4  fLwNhXatcSoQEI8XeFbrtg   bangers-and-lace-wicker-park-chicago-2
#
#                              name  \
# 0                    The Dearborn
# 1         Arctic Circle Taxidermy
# 2  Waterfall Glen Forest Preserve
# 3                Sideshow Gallery
# 4      Bangers & Lace Wicker Park
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/eSXeGi...      False
# 1  https://s3-media3.fl.yelpcdn.com/bphoto/EE06-p...      False
# 2  https://s3-media2.fl.yelpcdn.com/bphoto/HmSfAd...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/PBLs0J...      False
# 4  https://s3-media1.fl.yelpcdn.com/bphoto/fHPirO...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/the-dearborn-chicago-...          2074
# 1  https://www.yelp.com/biz/arctic-circle-taxider...             6
# 2  https://www.yelp.com/biz/waterfall-glen-forest...           141
# 3  https://www.yelp.com/biz/sideshow-gallery-chic...            24
# 4  https://www.yelp.com/biz/bangers-and-lace-wick...           609
#
#                                           categories  rating  \
# 0  [{'alias': 'tradamerican', 'title': 'American ...     4.5
# 1     [{'alias': 'taxidermy', 'title': 'Taxidermy'}]     5.0
# 2             [{'alias': 'parks', 'title': 'Parks'}]     4.5
# 3  [{'alias': 'galleries', 'title': 'Art Gallerie...     5.0
# 4  [{'alias': 'pubs', 'title': 'Pubs'}, {'alias':...     4.0
#
#                                          coordinates        transactions  \
# 0  {'latitude': 41.8842528, 'longitude': -87.6293...  [delivery, pickup]
# 1  {'latitude': 41.9528579711914, 'longitude': -8...                  []
# 2  {'latitude': 41.723035754423414, 'longitude': ...                  []
# 3  {'latitude': 41.922305053523, 'longitude': -87...                  []
# 4     {'latitude': 41.90357, 'longitude': -87.67023}  [delivery, pickup]
#
#   price                                           location         phone  \
# 0    $$  {'address1': '145 N Dearborn St', 'address2': ...  +13123841242
# 1   NaN  {'address1': '5637 W Irving Park Rd', 'address...  +17732868000
# 2   NaN  {'address1': 'Intersection Of Cass And Northga...  +16309337200
# 3    $$  {'address1': '2219 N Western Ave', 'address2':...  +17732761300
# 4    $$  {'address1': '1670 W Division St', 'address2':...  +17732526499
#
#     display_phone      distance
# 0  (312) 384-1242   4633.348427
# 1  (773) 286-8000   9201.472588
# 2  (630) 933-7200  31736.718353
# 3  (773) 276-1300   2063.047707
# 4  (773) 252-6499    645.478132

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 779 entries, 0 to 778
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             779 non-null    object
#  1   alias          779 non-null    object
#  2   name           779 non-null    object
#  3   image_url      779 non-null    object
#  4   is_closed      779 non-null    bool
#  5   url            779 non-null    object
#  6   review_count   779 non-null    int64
#  7   categories     779 non-null    object
#  8   rating         779 non-null    float64
#  9   coordinates    779 non-null    object
#  10  transactions   779 non-null    object
#  11  price          493 non-null    object
#  12  location       779 non-null    object
#  13  phone          779 non-null    object
#  14  display_phone  779 non-null    object
#  15  distance       779 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(12)
# memory usage: 92.2+ KB

# %% [markdown]
# # To convert the .json file to a compressed .csv.gz

# %%
# Convert the filename to a .csv.gz
#    csv_file = JSON_FILE.replace('.json', '.csv.gz')

# Save .csv file as a compressed csv
#    df.to_csv(csv_file, compression = 'gzip', index = False)
